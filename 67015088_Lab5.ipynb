# %% [markdown]
# <a href="https://colab.research.google.com/github/PIYA2PI/Copy_of_Lab3.ipynb/blob/main/67015088_Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# รหัสนักศึกษา : 66015088 ชื่อ : ปิยธิดา สุระ

# %% [markdown]
# Exercise 5.1 ให้เขียน function ชื่อ day_of_year(day, month ,year) โดยมีการคืนค่า คือ day_of_years เป็นวันที่ลำดับที่เท่าใดของปีคริสตศักราช year
# ปีที่เป็น Leap Year เดือนกุมภาพันธ์จะมี 29 วัน
# ให้สร้างฟังก์ชัน is_leap เพื่อตรวจสอบ leap year แยกออกมา และให้ฟังก์ชัน day_of_year เรียกใช้ is_leap อีกที

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
    if (year % 4 == 0):
        if (year % 100 == 0):
            if (year % 400 == 0):
                return True
            else:
                return False
        else:
            return True
    else:
        return False

def day_of_year(day, month, year):
    if is_leap(year)== True :
        days_in_month[1] = 29
    day_of_year = sum(days_in_month[:month - 1]) + day
    return day_of_year

# Testcases
print("Normal year (2023):")
print(f"1 Jan 2023: {day_of_year(1, 1, 2023)}")  # ควรได้ 1
print(f"1 Feb 2023: {day_of_year(1, 2, 2023)}")  # ควรได้ 32
print(f"1 Mar 2023: {day_of_year(1, 3, 2023)}")  # ควรได้ 60
print(f"31 Dec 2023: {day_of_year(31, 12, 2023)}")  # ควรได้ 365

print("\nLeap year (2024):")
print(f"1 Jan 2024: {day_of_year(1, 1, 2024)}")  # ควรได้ 1
print(f"29 Feb 2024: {day_of_year(29, 2, 2024)}")  # ควรได้ 60
print(f"1 Mar 2024: {day_of_year(1, 3, 2024)}")  # ควรได้ 61
print(f"31 Dec 2024: {day_of_year(31, 12, 2024)}")  # ควรได้ 366

print("\nCentury year, not a leap year (1900):")
print(f"1 Mar 1900: {day_of_year(1, 3, 1900)}")  # ควรได้ 60

print("\nCentury year, leap year (2000):")
print(f"1 Mar 2000: {day_of_year(1, 3, 2000)}")  # ควรได้ 61

print("\nMid-year dates:")
print(f"15 Jun 2023: {day_of_year(15, 6, 2023)}")  # ควรได้ 166
print(f"15 Jun 2024: {day_of_year(15, 6, 2024)}")  # ควรได้ 167 (Leap year)

print("\nLast day of each quarter:")
print(f"31 Mar 2023: {day_of_year(31, 3, 2023)}")  # ควรได้ 90
print(f"30 Jun 2023: {day_of_year(30, 6, 2023)}")  # ควรได้ 181
print(f"30 Sep 2023: {day_of_year(30, 9, 2023)}")  # ควรได้ 273
print(f"31 Dec 2023: {day_of_year(31, 12, 2023)}")  # ควรได้ 365
# Out:
# Normal year (2023):
# 1 Jan 2023: 1
# 1 Feb 2023: 32
# 1 Mar 2023: 60
# 31 Dec 2023: 365
#
# Leap year (2024):
# 1 Jan 2024: 1
# 29 Feb 2024: 60
# 1 Mar 2024: 61
# 31 Dec 2024: 366
#
# Century year, not a leap year (1900):
# 1 Mar 1900: 61
#
# Century year, leap year (2000):
# 1 Mar 2000: 61
#
# Mid-year dates:
# 15 Jun 2023: 167
# 15 Jun 2024: 167
#
# Last day of each quarter:
# 31 Mar 2023: 91
# 30 Jun 2023: 182
# 30 Sep 2023: 274
# 31 Dec 2023: 366

# %% [markdown]
# Exercise 5.2 ให้เขียนฟังก์ชัน เพิ่มเติมเป็น date_diff
# รับข้อมูลในรูปแบบ “dd-mm-yyyy” เช่น date_diff(“1-1-2018”, “1-1-2020”) จะได้ 731 วัน date_diff(“25-12-1999”, “9-3-2000”) จะได้ 76 วัน
# ให้เขียนฟังก์ชัน day_in_year โดยจะส่งค่าจำนวนวันของปี (365 หรือ 366) โดยรับข้อมูลเป็น ปี
# ส่งคืนข้อมูลเป็นจำนวนวันตั้งแต่วันที่แรก จนถึงวันที่สอง โดยรวมทั้ง 2 วันนั้นเข้าไปด้วย
# ให้สมมติว่าวันแรก จะต้องมาก่อนวันที่สองเสมอ ดังนั้นไม่ต้องตรวจสอบ

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
    if (year % 4 == 0):
        if (year % 100 == 0):
            if (year % 400 == 0):
                return True
            else:
                return False
        else:
            return True
    else:
        return False

def parse_date(date_str):
        day, month, year = map(int, date_str.split('-'))
        return day, month, year

def day_of_year(day, month, year):
    if is_leap(year)== True :
        days_in_month[1] = 29
    day_of_year = sum(days_in_month[:month - 1]) + day
    return day_of_year

def day_in_year(year):
    return 366 if is_leap(year) else 365

def date_diff(date1, date2):
  day1, month1, year1 = parse_date(date1)
  day2, month2, year2 = parse_date(date2)

  if year1 == year2 :
      sum = day_of_year(day2, month2, year2)-day_of_year(day1, month1, year1)
      return sum

  if year1 != year2 :
      if year1+1 == year2 :
          if is_leap(year1) == True :
            sum1 = 366-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)

          if is_leap(year1) == False :
            sum1 = 365-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)

          if is_leap(year2) == True :
            sum2 = day_of_year(day2, month2, year2)+1

          sum = sum1+sum2+1
          return sum


  if year2 - year1 >= 2 :
          if is_leap(year1) == True :
            sum1 = 366-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)

          if is_leap(year1) == False :
            sum1 = 365-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)



          sum3 = 0
          for i in range(year1+1,year2) :

            if is_leap(i) == True :
              sum3 += 366
            else :
              sum3 += 365
          sum = sum1+sum2+sum3+1
          return sum






# ทดสอบฟังก์ชัน
print(date_diff("1-1-2018", "1-1-2020"))  # ควรได้ 731
print(date_diff("25-12-1999", "9-3-2000"))  # ควรได้ 76
print(date_diff("1-1-2000", "1-1-2001"))  # ควรได้ 367 (ปี 2000 เป็น leap year)
print(date_diff("1-1-2001", "1-1-2002"))  # ควรได้ 366 (ปี 2001 ไม่ใช่ leap year)
print(date_diff("1-3-2000", "1-3-2001"))  # ควรได้ 367 (ข้ามปี leap year)
print(date_diff("1-1-2023", "31-12-2023"))  # ควรได้ 365 (ทั้งปี 2023)
# Out:
# 731
# 76
# 367
# 366
# 367
# 365

# %% [markdown]
# Exercise 5.3 จากโปรแกรม 5.2 ให้เขียนฟังก์ชัน date_diff  เพิ่มเติม โดยให้มีการตรวจสอบ
# วันที่ต้องเป็นวันที่ถูกต้องของเดือนนั้นๆ
# เดือนต้องอยู่ระหว่าง 1-12
# เดือนกุมภาพันธ์ของปีที่มี Leap Year เท่านั้นที่จะมี 29 วันได้
# หากข้อมูล Input ผิดพลาด ให้ Return -1

# %%
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
    if (year % 4 == 0):
        if (year % 100 == 0):
            if (year % 400 == 0):
                return True
            else:
                return False
        else:
            return True
    else:
        return False


def day_of_year(day, month, year):
    if is_leap(year)== True :
        days_in_month[1] = 29
    day_of_year = sum(days_in_month[:month - 1]) + day
    return day_of_year

def day_in_year(year):
    return 366 if is_leap(year) else 365

def date_diff(date1, date2):

  d1= date1.split("-")
  d2= date2.split("-")

  if len(d1) != 3 :
    return -1
  if len(d2) != 3 :
    return -1

  day1 = d1[0]
  day2 = d2[0]
  month1 = d1[1]
  month2 = d2[1]
  year1 = d1[2]
  year2 = d2[2]

  day1 = int(d1[0])
  day2 = int(d2[0])
  month1 = int(d1[1])
  month2 = int(d2[1])
  year1 = int(d1[2])
  year2 = int(d2[2])


  if is_leap(year1) == True and month1 == 2 and day1 > 29  :
    return -1
  if is_leap(year1) == False and month1 == 2 and day1 == 29  :
    return -1


  if month1 > 12 :
    return -1
  if month2 > 12 :
    return -1

  if day1 >  days_in_month[month1-1] :
    return -1
  if day2 >  days_in_month[month2-1] :
    return -1


  if year1 == year2 :
      sum = day_of_year(day2, month2, year2)-day_of_year(day1, month1, year1)
      return sum

  if year1 != year2 :
      if year1+1 == year2 :
          if is_leap(year1) == True :
            sum1 = 366-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)

          if is_leap(year1) == False :
            sum1 = 365-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)

          if is_leap(year2) == True :
            sum2 = day_of_year(day2, month2, year2)+1

          sum = sum1+sum2+1
          return sum


  if year2 - year1 >= 2 :
          if is_leap(year1) == True :
            sum1 = 366-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)

          if is_leap(year1) == False :
            sum1 = 365-day_of_year(day1, month1, year1)
            sum2 = day_of_year(day2, month2, year2)



          sum3 = 0
          for i in range(year1+1,year2) :

            if is_leap(i) == True :
              sum3 += 366
            else :
              sum3 += 365
          sum = sum1+sum2+sum3+1
          return sum



# ทดสอบฟังก์ชัน
print(date_diff("1-1-2018", "1-1-2020"))  # ควรได้ 731
print(date_diff("25-12-1999", "9-3-2000"))  # ควรได้ 76
print(date_diff("1-1-2000", "1-1-2001"))  # ควรได้ 367 (ปี 2000 เป็น leap year)
print(date_diff("1-1-2001", "1-1-2002"))  # ควรได้ 366 (ปี 2001 ไม่ใช่ leap year)
print(date_diff("1-3-2000", "1-3-2001"))  # ควรได้ 367 (ข้ามปี leap year)
print(date_diff("1-1-2023", "31-12-2023"))  # ควรได้ 365 (ทั้งปี 2023)

# ทดสอบกรณีข้อมูลไม่ถูกต้อง
print(date_diff("31-4-2023", "1-5-2023"))  # ควรได้ -1 (เดือนเมษายนมี 30 วัน)
print(date_diff("29-2-2023", "1-3-2023"))  # ควรได้ -1 (ปี 2023 ไม่ใช่ leap year)
print(date_diff("1-13-2023", "1-1-2024"))  # ควรได้ -1 (เดือนไม่ถูกต้อง)
print(date_diff("abc", "1-1-2024"))  # ควรได้ -1 (รูปแบบวันที่ไม่ถูกต้อง)
# Out:
# 731
# 76
# 367
# 366
# 367
# 365
# -1
# -1
# -1
# -1

# %% [markdown]
# 1.	ปลาหมอคางดำเพศเมีย 1 ตัว เมื่ออายุครบ 2 เดือน จะสามารถสืบพันธ์ได้ โดยระยะเวลาตั้งท้องจนถึง
# วางไข่ของตัวเมียจะใช้เวลา 21 วัน และฟักในปากเพศผู้อีก 7 วัน (สามารถรวมเป็น 1 เดือนได้) โดยออกไข่ครั้งละ 300 ฟอง กำหนดให้ไข่ฟักเป็นเพศผู้และเพศเมียอย่างละครึ่ง และเมื่อวางไข่แล้วจะสามารถสืบพันธ์ต่อได้ทันที กำหนดให้ปลามีอายุ 5 ปี และปลาทั้งหมดจะตาย p% ทุก 1 เดือน จงหาว่าปลาหมอคางดำหลุดจากฟาร์ม n ตัวเป็นเพศผู้และเพศเมียอย่างละครึ่ง จงเขียนโปรแกรมรับค่า n และ p ให้แสดงผลจำนวนปลาทุก 3 เดือน เป็นเวลา 10 ปี ให้เขียนเป็นฟังก์ชัน ชื่อ simulate_fish_population()

# %%
import math

def simulate_fish_population(n, p):
    l_egg = []
    l_baby = [0]
    l_adult = [n]
    k=0

    for i in range(12*10):
        if i == 0:
            l_egg.append((sum(l_adult)/2)*300)
            print(i+1,"Egg:",int(l_egg[i]),"Baby:",int(l_baby[i]),"Adult:",sum(l_adult),"Fish:",n)

        elif i > 0:
            l_baby.append(l_egg[i-1]*(100-p)/100)

            l_egg.append((sum(l_adult)/2)*300)

            l_adult.append(l_baby[i-1]*(100-p)/100)

            print(i+1,"Egg:",int(l_egg[i]),"Baby:",int(l_baby[i]),"Adult:",sum(l_adult),"Fish:",sum(l_adult)+int(l_baby[i]))

        for j in range(len(l_adult)):
            l_adult[j] = round((l_adult[j]*(100-p)/100))

        #fish dead when 5 year
        if i >= 59:
            l_adult[k] =0
            k=k+1



n = int(input("Initial number of fish :"))
p = int(input("Monthly mortality rate : "))
simulate_fish_population(n, p)

# Run simulation
n = 2  # Initial number of fish
p = 10  # Monthly mortality rate

# simulate_fish_population(n, p)

# ถ้าเริ่มต้นด้วยปลา 2 ตัว ตายเดือนละ 10%
# เดือนที่ 1 ไข่ 300 ไบ
# เดือนที่ 2 ไข่ 300 ใบ + ลูกปลา 270 ตัว
# เดือนที่ 3 ไข่ 300 ใบ + ลูกปลา 270 ตัว + ปลาโตเต็มวัย 243 ตัว + 2 = 515 ตัว
# Out:
# Initial number of fish :2
# Monthly mortality rate : 10
# 1 Egg: 300 Baby: 0 Adult: 2 Fish: 2
# 2 Egg: 300 Baby: 270 Adult: 2.0 Fish: 272.0
# 3 Egg: 300 Baby: 270 Adult: 245.0 Fish: 515.0
# 4 Egg: 33150 Baby: 270 Adult: 464.0 Fish: 734.0
# 5 Egg: 62700 Baby: 29835 Adult: 661.0 Fish: 30496.0
# 6 Egg: 89250 Baby: 56430 Adult: 27446.5 Fish: 83876.5
# 7 Egg: 3705150 Baby: 80325 Adult: 75488.0 Fish: 155813.0
# 8 Egg: 10190700 Baby: 3334635 Adult: 140230.5 Fish: 3474865.5
# 9 Egg: 18931050 Baby: 9171630 Adult: 3127378.5 Fish: 12299008.5
# 10 Egg: 422196150 Baby: 17037945 Adult: 11069108.0 Fish: 28107053.0
# 11 Egg: 1494329550 Baby: 379976535 Adult: 25296347.5 Fish: 405272882.5
# 12 Egg: 3415006950 Baby: 1344896595 Adult: 364745594.5 Fish: 1709642189.5
# 13 Egg: 49240655400 Baby: 3073506255 Adult: 1538677971.5 Fish: 4612184226.5
# 14 Egg: 207721526250 Baby: 44316589860 Adult: 4150965804.5 Fish: 48467555664.5
# 15 Egg: 560380383750 Baby: 186949373625 Adult: 43620800099.0 Fish: 230570173724.0
# 16 Egg: 5888808013050 Baby: 504342345375 Adult: 207513156349.5 Fish: 711855501724.5
# 17 Egg: 28014276107100 Baby: 5299927211745 Adult: 640669951551.5 Fish: 5940597163296.5
# 18 Egg: 86490443459250 Baby: 25212848496390 Adult: 5346537446965.5 Fish: 30559385943355.5
# 19 Egg: 721782555340350 Baby: 77841399113325 Adult: 27503447349020.0 Fish: 105344846462345.0
# 20 Egg: 3712965392117700 Baby: 649604299806315 Adult: 94810361816110.5 Fish: 744414661622425.5
# 21 Egg: 12799398845175000 Baby: 3341668852905930 Adult: 669973195460183.5 Fish: 4011642048366113.5
# 114 Egg: 10860091247256951066372392792952278242101304933920555951184576479881266809890930688 Baby: 1915872405635336188724092349619657841174802438054519161215522079362613246271946752 Adult: 4.1040988913067715e+80 Fish: 2.3262822947660132e+81
# 115 Egg: 55405335032641415148880463510703537042666711584064360412347579476645216949452668928 Baby: 9774082122531257307732486871189040151241928791510034037923339958921764184082350080 Adult: 2.093654065289412e+81 Fish: 1.186773618782067e+82
# 116 Egg: 282643298814070647397541554786792781670651990448508157313269062231451752274986008576 Baby: 49864801529377274981989750517165173071750794776639458052970042656009319309687914496 Adult: 1.0680962569038604e+82 Fish: 6.054576409841588e+82
# 117 Egg: 1441929946820211359195757554402593277929657527375814505718432324928465743972195631104 Baby: 254378968932663571873808732447857585636780756595805072127084386992077584606043308032 Adult: 5.449118768857429e+82 Fish: 3.0887015662123785e+83
# 118 Egg: 7356310337957528878142441815545590423884445390488926575870505871568827207245350567936 Baby: 1297736952138190287980053800123869457337527983485346671875735706532993124223640666112 Adult: 2.779831409591141e+83 Fish: 1.5757200930973044e+84
# 119 Egg: 37527724029480397562776726583138530393133713998275367958563496928822191205492321157120 Baby: 6620679304161775817784538964226936695627104294514397607005730980152280607457709916160 Adult: 1.4181480837875739e+84 Fish: 8.03882738794935e+84
# 120 Egg: 191449991311322469815931377163285437198893526834106772399014286507689182271446796206080 Baby: 33774951626532357806499053924824677353820342598447831162707147235939972084943089041408 Adult: 7.234944649154414e+84 Fish: 4.100989627568677e+85

# %% [markdown]
# 2.	ให้เขียน function find_mismatch ซึ่งรับ string มา 2 ค่า โดยจะส่งค่ากลับดังนี้
# - 0 เมื่อ string ทั้ง 2 ตัว เหมือนกัน โดยไม่สนใจ case
# - 1 เมื่อ string 1 จะเหมือน string 2 โดยการลบและ/หรือเพิ่มตัวอักษรเพียง 1 ตัว
# - 2 เมื่อ string ไม่เข้าเกณฑ์ 0 หรือ 1
#
#
# | String  1| 	String2	|ผลลัพธ์|
# |----------|----------|------|
# |Python|	Java	|2|
# |book	 |  boot	|1|
# |fan	 |  fun	  |1|
# |sin	 | sink	  |1 เพราะเพิ่ม k ใน str2 แล้วจะเหมือนกัน
# |Dog	 | dog	  |0
# |poke	 | spoke	|1 เพิ่ม s ใน str2 แล้วเหมือนกัน
# |poker |	poke	|1 ตัด r ใน str1 ออกแล้วเหมือนกัน

# %%
def find_mismatch(str1, str2):
    if str1.lower() == str2.lower():
        return(0)

    elif abs(len(str1)-len(str2)) <= 1:

        #remove from str1
        for i  in range(len(str1)):
            if str1[:i] + str1[i+1:] == str2:
                return(1)

        #remove from str2
        for i  in range(len(str2)):
            if str2[:i] + str2[i+1:] == str1:
                return(1)

        #remove from both
        for i in range(len(str1)):
            if str1[:i] + str1[i+1:] == str2[:i] + str2[i+1:]:
                return(1)

    else:
        return(2)


str1, str2 = input("Enter two string: ").split()
print(f"{str1} , {str2} # {find_mismatch(str1, str2)}")

#test
print(find_mismatch("Python", "Java"))#2
print(find_mismatch("book", "boot"))#1
print(find_mismatch("fan", "fun"))#1
print(find_mismatch("sin", "sink"))#1
print(find_mismatch("Dog", "dog"))#0
print(find_mismatch("poke", "spoke"))#1
print(find_mismatch("poker", "poke"))#1
# Out:
# Enter two string: Python", "Java
# Python", , "Java # 2
# 2
# 1
# 1
# 1
# 0
# 1
# 1

# %% [markdown]
# 3.	จากข้อ 1 ให้เขียนฟังก์ชันชื่อ spelling_correction โดยรับ 2 argument ตัวแรกเป็นประโยค (string) และตัวที่ 2 เป็น list ของคำ (correct_spells) โดยฟังก์ชันนี้มีหน้าที่ตรวจสอบแต่ละ word ใน input string กับคำที่อยู่ใน correct_spells โดยค่าที่คืนกลับมาจะมีดังนี้ (พยายามเรียกใช้ฟังก์ชันในข้อ 1)
# -	ถ้าคำที่อยู่ในประโยค ตรงกับคำที่อยู่ใน correct_spells ทุกอย่าง ก็จะ copy ไปที่ output string
# -	ถ้าคำที่อยู่ในประโยค ต่างจากคำที่อยู่ใน correct_spells โดยต่างกัน 1 ตัวอักษร โดยการเปลี่ยน การเพิ่ม หรือการลบ 1 ตัวอักษร คำที่อยู่ในประโยคจะถูกเปลี่ยนโดยคำที่อยู่ใน correct_spells และนำไปใส่ output string
# -	ถ้าคำที่ไม่พบในเงื่อนไขข้างต้นให้นำคำนั้นไปใส่ output string ได้เลย
# -	คำที่ประกอบด้วย 1 หรือ 2 ตัวอักษรจะไม่ตรวจสอบ ให้นำคำนั้นไปใส่ output string ได้เลย
# -	ถ้ามี 2 คำใน correct_spells ที่ตรงตามเงื่อนไข ให้ใช้คำแรก
# -	ไม่สนใจตัวใหญ่ ตัวเล็ก
# -	Input string จะมีได้เพียงอักษรภาษาอังกฤษเท่านั้น
# -	ในแต่ละคำจะคั่นด้วย 1 space ถ้ามี space มากกว่านั้นให้ตัดออก และตัด space จากหัวท้ายประโยค
#
# |ประโยค	|correct_spells	|output string |
# |-------|---------------|-------------|
# |Thes is the Firs cas	|[‘that’,’first’,’case’,’car’]|	thes is the first car|
# |programming is fan and easy	|[‘programming’,’this’,’fun’,’easy’,book’]	|programming is fun and easy|
# |Thes is vary essy	|[‘this’,’is’,’very’,’easy’]	|this is very easy|
# |Wee ipve Pythen	|[‘we’,’live’,’ln’,’Python’]	|we live python|

# %%
def find_mismatch(str1, str2):
    str1 = str1.lower()
    str2 = str2.lower()

    mismatch_count = 0

    for i in range(len(str1)):
        if i < len(str2):
            if str1[i] != str2[i]:
                mismatch_count += 1
        else:
            mismatch_count += 1
    if len(str2) > len(str1):
        mismatch_count += len(str2) - len(str1)

    if mismatch_count == 0:
        return 0
    elif mismatch_count == 1:
        return 1
    else:
        return 2


def spelling_correction(input_string, correct_spells):
  input_string = input_string.split(" ")
  input_string_str = ' '.join(input_string).lower()
  correct_spells_str = ' '.join(correct_spells).lower()
  result = []
  for i in input_string_str:
    if i not in "abcdefghijklmnopqrstuvwxyz ":
      return "Character Incorrect "
  c = 0

  input_string_len = len(input_string)
  a = find_mismatch(input_string_str,correct_spells_str)

  for i in input_string:
    c2 = 0
    for j in correct_spells:
        if i == j:
          c += 1
        if c == len(correct_spells):
          input_string = ' '.join(input_string)
          return input_string
        else:
          if find_mismatch(i,j) == 2 and c2 == len(correct_spells)-1:
            result.append(i)
          elif find_mismatch(i, j) == 1:
            result.append(j)
            break
          else:
            c2 += 1
  result = ' '.join(result)
  return result


print(spelling_correction("Thes is the Firs cas",correct_spells))
# Out:
# Thes is the first car

# %% [markdown]
# 5. ให้เขียนฟังก์ชัน find_word_vertical ซึ่งจะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตามคอลัมน์ของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบ จะส่งคืน row index และ column index ของตัวอักษรแรก ถ้าไม่พบจะส่งคืน None
#
# ตัวอย่าง
# ```
# 	crosswords=[['s','d','o','g'],
#               ['c','u','c','m'],
#               ['a','c','a','t'],
#               ['t',' e','t','k']]
# 	word='cat'
# 	find_word_vertical(crosswords,word)
# ```
#
# Output
#    [1,0]

# %%
def find_word_vertical(crosswords,word):
    z=[list(i) for i in zip(*crosswords)]
    for rows in z:
        row_index = z.index(rows)
        single_row = ''.join(rows)
        column_index = single_row.find(word)
        if column_index >= 0:
            return([column_index, row_index])

crosswords=[['s','d','o','g'],
            ['c','u','c','m'],
            ['a','c','a','t'],
            ['t',' e','t','k']]
word='cat'
print(find_word_vertical(crosswords,word))
# Out:
# [1, 0]

# %% [markdown]
# 6.	ให้เขียนฟังก์ชัน capitalize_word_in_crossword จะรับ list ขนาด 2 มิติ ของตัวอักษร (คล้ายกับเกม cross word) และ word ซึ่งเป็น string เป็น argument โดยฟังก์ชันนี้ จะค้นหาตาม row และ column ของ list เพื่อหาตำแหน่งที่มีอักษรตรงกับคำใน word ถ้าพบจะเปลี่ยนเป็นตัวใหญ่และ และส่งคืน list ที่แก้ไขแล้ว แต่ถ้าไม่เจอจะส่ง list เดิมกลับมา ให้ใช้ฟังก์ชันตามข้อ 3 และ 4 ช่วย
#
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','x','a','t'],
#             ['t','e','t','k']]
# word='cat'
# capitalize_word_in_crossword(crosswords,word)
# ```
# จะส่งค่ากลับ
# ```
#  [['s','d','o','g'],
#   ['C','u','c','m'],
#   ['A','x','a','t'],
#   ['T','e','t','k']]
# ```
# ```
# crosswords=[['s','d','o','g'],
#             ['c','u','c','m'],
#             ['a','c','a','t'],
#             ['t','e','t','k']]
# word='cat'
# capitalize_word_in_crossword(crosswords,word)
# จะส่งค่ากลับ
# [['s','d','o','g'],
#  ['c','u','c','m'],
#  ['a','C','A','T'],
#  ['t','e','t','k']]
# ```

# %%
def find_word_vertical(crosswords,word):
    z=[list(i) for i in zip(*crosswords)]
    for rows in z:
        row_index = z.index(rows)
        single_row = ''.join(rows)
        column_index = single_row.find(word)
        if column_index >= 0:
            return([column_index, row_index])

def find_word_horizontal(crossword, word):
    for row in crossword:
        joined_row = ''.join(row)
        if word in joined_row:
            start_index = joined_row.index(word)
            return crossword.index(row), start_index
    return None

def capitalize_word_in_crossword(crosswords, word):

    find_hor = find_word_horizontal(crosswords, word)
    if find_hor != None:
        row, start_col = find_hor
        for i in range(len(word)):
            crosswords[find_hor[0]][find_hor[1] + i] = crosswords[find_hor[0]][find_hor[1] + i].upper()
        return crosswords
    else:
        find_ver = find_word_vertical(crosswords,word)
        if find_ver != None:
            for i in range(len(word)):
                crosswords[find_ver[0] + i][find_ver[1]] = crosswords[find_ver[0] + i][find_ver[1]].upper()
            return crosswords
    if find_ver == None and find_hor == None:
        return(crosswords)




crosswords=[['s','d','o','g'],
            ['c','u','c','m'],
            ['a','c','a','t'],
            ['t','e','t','k']]
word='cat'
sum = capitalize_word_in_crossword(crosswords, word)
for row in sum:
    print(row)
# Out:
# ['s', 'd', 'o', 'g']
# ['c', 'u', 'c', 'm']
# ['a', 'C', 'A', 'T']
# ['t', 'e', 't', 'k']
